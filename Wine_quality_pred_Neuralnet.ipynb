# %%
import pandas as pd

# %%
#add wine dataset
df = pd.read_csv('https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv')
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %% [markdown]
# ### Statsitics of wine data

# %%
df.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %%
#same data with simplier to read
df.describe().transpose()
# Out:
#                       count        mean         std     min       25%  \
# Wine                  178.0    1.938202    0.775035    1.00    1.0000
# Alcohol               178.0   13.000618    0.811827   11.03   12.3625
# Malic.acid            178.0    2.336348    1.117146    0.74    1.6025
# Ash                   178.0    2.366517    0.274344    1.36    2.2100
# Acl                   178.0   19.494944    3.339564   10.60   17.2000
# Mg                    178.0   99.741573   14.282484   70.00   88.0000
# Phenols               178.0    2.295112    0.625851    0.98    1.7425
# Flavanoids            178.0    2.029270    0.998859    0.34    1.2050
# Nonflavanoid.phenols  178.0    0.361854    0.124453    0.13    0.2700
# Proanth               178.0    1.590899    0.572359    0.41    1.2500
# Color.int             178.0    5.058090    2.318286    1.28    3.2200
# Hue                   178.0    0.957449    0.228572    0.48    0.7825
# ...

# %% [markdown]
# ##### This is a classification problem, label is Wine column and remaining are the feature columns.
# Assign feature and label columns

# %%
X = df.drop('Wine', axis = 1) # drop the wine column from the dataset. This is features
y = df['Wine'] # this is label

# %%
X.columns
# Out:
# Index(['Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols', 'Flavanoids',
#        'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue', 'OD', 'Proline'],
#       dtype='object')

# %%
#get test train split
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X,y) #By default it will assign 75 % of the data for training and 25 % for testing

# %%
#Standardize the data: 
#We need to scale the data, due the large deviation in the values. 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()

# %%
#Transform the train data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Neural network model using Multi-Layer Perceptron Classifier Model

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(hidden_layer_sizes = (130,13,13), max_iter = 1500)
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(130, 13, 13), max_iter=1500)

# %%
#Predictions
pred = mlp.predict(X_test)

# %%
 from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[13  1  1]
#  [11  6  1]
#  [ 5  0  7]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.93      0.87        15
#            2       0.93      0.78      0.85        18
#            3       0.92      1.00      0.96        12
#
#     accuracy                           0.89        45
#    macro avg       0.89      0.90      0.89        45
# weighted avg       0.89      0.89      0.89        45
